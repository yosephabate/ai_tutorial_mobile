# %% [markdown]
# <a href="https://colab.research.google.com/github/yosephabate/ai_tutorial_mobile/blob/main/ai_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

print(tf.__version__)

model = keras.Sequential(keras.layers.Dense(units=1, input_shape=[1]))
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
print(model.predict([10.0]))
# Out:
# 2.7.0
# Epoch 1/500
# 1/1 [==============================] - 0s 248ms/step - loss: 48.1273
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 38.2512
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 30.4731
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 24.3460
# Epoch 5/500
# 1/1 [==============================] - 0s 20ms/step - loss: 19.5178
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 15.7117
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 12.7100
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 10.3412
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4706
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9920
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.8219
# Epoch 12/500
# ...
