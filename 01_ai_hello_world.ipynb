# %% [markdown]
# <a href="https://colab.research.google.com/github/yosephabate/ai_tutorial_mobile/blob/main/01_ai_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

print(tf.__version__)

model = Sequential(Dense(units=1, input_shape=[1]))
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
print(model.predict([10.0]))
# Out:
# 2.7.0
# Epoch 1/500
# 1/1 [==============================] - 0s 262ms/step - loss: 0.5845
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5716
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5592
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5471
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5355
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5241
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5131
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5024
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4919
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4816
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4716
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4619
# ...
